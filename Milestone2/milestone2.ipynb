# %% [markdown]
# Screenshot of Original Graph

# %% [markdown]
# ![Original Graph](replication_study_screenshot.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# This is the data used for the visualization
data_incident_plot = pd.read_csv("Incidents_Year.csv")

# again, just inspecting the data
data_incident_plot.head()
# Out:
#    Year  Incidents
# 0  1784          6
# 1  1785          0
# 2  1786          0
# 3  1787          5
# 4  1788          1

# %%
# creating the canvas size
plt.figure(figsize=(20, 10)) 

# setting the x variable
x = range(len(data_incident_plot["Incidents"]))

# plotting
plt.plot(x, data_incident_plot["Incidents"])
plt.xticks(x, data_incident_plot["Year"])
plt.xlabel("Year")
plt.ylabel("Extralegal Collective Incidents Resulting in Fatalities")
plt.xticks(rotation = 90)
plt.title("figure 1: Incidents of Extralegal Collective Violence Resulting in Fatalities, 1783-1865")

plt.show()

# %% [markdown]
# Commentary: This is the most important part. In the Markdown cells of your notebook, you must narrate your process (aim for roughly 250 words, total). If your graph looks different fro theirs, explain why.
# - Did you have access to less data?
# - Did they apply a filter they didn't mention in the text?
# - Is their chart actually misleading based on what you found?
